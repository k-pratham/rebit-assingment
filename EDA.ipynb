# %% [markdown]
# <a href="https://colab.research.google.com/github/k-pratham/rebit-assingment/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("/Iris.csv")
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.shape
# Out:
# (150, 6)

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.value_counts("Species")
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
sns.countplot(x ="Species", data = df)
# Out:
# <Axes: xlabel='Species', ylabel='count'>

# %%
df_sepal_length = df.copy()

# %%
df_sepal_length= df.loc[df["SepalLengthCm"] >= 5.0]

# %%
df_sepal_length.head()
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa

# %%
def sepal_length_separation(row):
  if row["SepalLengthCm"]>= 5.0:
    row["Sepal_separation"]="above 5"
  else:
    row["Sepal_separation"] = "below 5"
  return row

# %%
df_sepal_length = df_sepal_length.apply(sepal_length_separation, axis=1)
df_sepal_length.head()
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
#
#    Sepal_separation
# 0           above 5
# 4           above 5
# 5           above 5
# 7           above 5
# 10          above 5

# %%
sns.scatterplot(data = df, x = "SepalLengthCm", y = "SepalWidthCm", hue = "Species")
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
sns.scatterplot(data = df, x = "PetalLengthCm", y = "PetalWidthCm", hue = "Species")
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %%
df.drop("Id",axis=1, inplace=True)

# %%
sns.pairplot(data = df, hue = "Species")

# %%
sns.boxplot(data = df, x = "Species",y="SepalLengthCm")
# Out:
# <Axes: xlabel='Species', ylabel='SepalLengthCm'>

# %%
figure = plt.figure(figsize = (10,5))
plt.subplot(x = "Species", y = "SepalLengthCm", axis = [0][0])
plt.subplot(x = "Species", y = "SepalWidthCm", axis = [0][1])
plt.subplot(x = "Species", y = "PetalLengthCm", axis = [1][0])
plt.subplot(x = "Species", y = "PetalWidthCm", axis = [1][1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-d36a84aa1841> in <cell line: 2>()
#       1 figure = plt.figure(figsize = (10,5))
# ----> 2 plt.subplot(x = "Species", y = "SepalLengthCm", axis = [0][0])
#       3 plt.subplot(x = "Species", y = "SepalWidthCm", axis = [0][1])
#       4 plt.subplot(x = "Species", y = "PetalLengthCm", axis = [1][0])
#       5 plt.subplot(x = "Species", y = "PetalWidthCm", axis = [1][1])
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1435     else:
#    1436         # we have exhausted the known Axes and none match, make a new one!
# -> 1437         ax = fig.add_subplot(*args, **kwargs)
#    1438
#    1439     fig.sca(ax)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
# ...

# %%
figure = plt.figure(figsize = (10,5))

plt.subplot(2, 2, 1)
plt.plot(df["Species"], df["SepalLengthCm"], 'o')
plt.xlabel("Species")
plt.ylabel("SepalLengthCm")

plt.subplot(2, 2, 2)
plt.plot(df["Species"], df["SepalWidthCm"], 'o')
plt.xlabel("Species")
plt.ylabel("SepalWidthCm")

plt.subplot(2, 2, 3)
plt.plot(df["Species"], df["PetalLengthCm"], 'o')
plt.xlabel("Species")
plt.ylabel("PetalLengthCm")

plt.subplot(2, 2, 4)
plt.plot(df["Species"], df["PetalWidthCm"], 'o')
plt.xlabel("Species")
plt.ylabel("PetalWidthCm")

plt.tight_layout()
plt.show()

# %%
def graph(y):
    sns.boxplot(x="Species", y=y, data=df)

plt.figure(figsize=(10,10))

plt.subplot(221)
graph('SepalLengthCm')

plt.subplot(222)
graph('SepalWidthCm')

plt.subplot(223)
graph('PetalLengthCm')

plt.subplot(224)
graph('PetalWidthCm')

plt.show()

# %%
sns.boxplot(data = df,x="SepalWidthCm")
# Out:
# <Axes: xlabel='SepalWidthCm'>

# %%
Q1 = np.percentile(df['SepalWidthCm'], 25,
                interpolation = 'midpoint')

Q3 = np.percentile(df['SepalWidthCm'], 75,
                interpolation = 'midpoint')
IQR = Q3 - Q1

print("Old Shape: ", df.shape)

upper = np.where(df['SepalWidthCm'] >= (Q3+1.5*IQR))

lower = np.where(df['SepalWidthCm'] <= (Q1-1.5*IQR))

df.drop(upper[0], inplace = True)
df.drop(lower[0], inplace = True)

print("New Shape: ", df.shape)

sns.boxplot(x='SepalWidthCm', data=df)
# Out:
# Old Shape:  (150, 5)
# New Shape:  (146, 5)
# <Axes: xlabel='SepalWidthCm'>

# %%
bins = [4, 5, 6, 8]  # Define ranges
labels = ['Small', 'Medium', 'Large']
df['sepal_length_bin'] = pd.cut(df['SepalLengthCm'], bins=bins, labels=labels, include_lowest=True)

# Check the distribution of sepal length bins
print(df['sepal_length_bin'].value_counts())
# Out:
# sepal_length_bin
# Large     61
# Medium    54
# Small     31
# Name: count, dtype: int64

# %%
df["sepal_length_bin"].value_counts().plot.barh()
# Out:
# <Axes: ylabel='sepal_length_bin'>

# %%
pd.pivot_table(data = df, values='PetalLengthCm', index='sepal_length_bin', columns='Species', aggfunc='mean')
# Out:
# <ipython-input-35-1bb578cc620d>:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pd.pivot_table(data = df, values='PetalLengthCm', index='sepal_length_bin', columns='Species', aggfunc='mean')
# Species           Iris-setosa  Iris-versicolor  Iris-virginica
# sepal_length_bin
# Small                1.428571         3.300000        4.500000
# Medium               1.515789         4.118519        5.012500
# Large                     NaN         4.585000        5.682927
